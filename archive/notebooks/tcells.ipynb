# %%
import pandas as pd

# %%
df = pd.read_csv('../data/state_classif.csv',index_col='state')

# %%
df
# Out:
#                   0          1         2          3          4         5  \
# state
# Precursor  1.727896   5.245075  0.506406   0.175137   0.118281 -1.036177
# Precursor  0.536239  -6.273371 -0.683618  -1.751520   0.093019  1.315888
# Precursor  2.904423   7.327612 -3.331428   0.056643  -0.269898  0.917983
# Precursor  3.463615  11.274001 -8.993727   4.527588  -2.324541  6.527379
# Precursor  0.411735   2.011680  4.361190  -0.335676   1.774343 -1.488595
# ...             ...        ...       ...        ...        ...       ...
# Exhausted  0.389498   2.253546  3.321128   0.920717   0.252647 -0.292614
# Exhausted  2.463141   0.849098  1.118300  -1.318845   1.324657 -1.353007
# Exhausted  1.775260   3.082098  1.882630  -4.928707   3.483102 -0.659295
# Exhausted  3.820602  13.057975 -1.470009 -10.210454 -13.326870 -8.411932
# Exhausted  1.052194   8.192725  2.949652  -6.292629  -5.055536 -4.867247
#
#                   6         7         8         9  ...        20        21  \
# ...

# %%
df.index.unique()
# Out:
# Index(['Precursor', 'Proliferation', 'Interferon', 'Stem', 'Effector',
#        'Memory', 'Exhausted'],
#       dtype='object', name='state')

# %%
df = pd.read_csv('../data/perturb_classif.csv', index_col = "PERTURB")

# %%
df
# Out:
#                 0         1         2         3         4         5         6  \
# PERTURB
# 3        3.920652  4.914614 -1.498024 -4.668012 -0.537703 -2.057116  0.711000
# 3        1.697231 -7.494428 -1.988911  1.441377 -2.819204 -0.683453 -1.535574
# 1        2.179463  2.499904 -0.108501  3.178330  0.444651 -1.631904 -0.245926
# 3        0.190689 -7.405192 -0.050543 -0.977836 -1.602138  2.136909 -0.838452
# 0        2.091841  0.963654 -0.648943 -0.038423 -0.595929 -1.472585 -1.169796
# ...           ...       ...       ...       ...       ...       ...       ...
# 1        2.704359 -0.763612 -1.764985 -0.794080  1.611960 -1.549226 -1.642926
# 2        3.143553  3.543000 -0.935734 -0.425998  2.411621 -1.509725 -0.535854
# 0        1.052194  8.192725  2.949652 -6.292629 -5.055536 -4.867247  5.320174
# 4        1.300797  4.642959  1.631708  2.598036  1.196024  1.597254  0.750860
# 4        1.392489 -5.630458 -0.532082 -1.656567 -1.745688 -0.229506  0.414737
#
# ...
